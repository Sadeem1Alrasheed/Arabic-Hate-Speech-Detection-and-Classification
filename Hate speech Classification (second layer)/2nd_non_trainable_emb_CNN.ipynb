# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow
import random

# Set random seed for reproducibility
np.random.seed(0)
tensorflow.random.set_seed(0)
random.seed(0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.layers import Embedding, SimpleRNN, GRU, LSTM, Bidirectional, Dense, Dropout, Conv1D, GlobalMaxPooling1D
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Load and preprocess the data
df = pd.read_csv('/content/drive/MyDrive/seema/2nd_data.csv')
df.head()
# Out:
#                                                Tweet  True Label   Sub  \
# 0  هذا تاريخ الخبيث اللي تروجله ياوهمي متطرف اخون...           1  P-HS
# 1  في نتألم جميعا كيف اصبح حال الشعب اليمني المظل...           1  P-HS
# 2  من كان يتوقع أن السعودية التي كانت تعاقب من يف...           1  R-HS
# 3  لن نجد اخس واذل من مان يستهدفون المدنيين ويقتل...           1  S-HS
# 4        إمعة وغبي وكذاب صفات الرئيس المنتدب الفطرية           1  P-HS
#
#    sub_labels
# 0           0
# 1           0
# 2           1
# 3           2
# 4           0

# %% [markdown]
# ### **Preprocessing**

# %%
X = df['Tweet'].astype(str)
y = df['sub_labels']

# %%
from tensorflow.keras.utils import to_categorical
# Convert integer labels to one-hot encoded vectors
y_cat = to_categorical(y, num_classes=3)

# %% [markdown]
# ### **Tokenization and padding**

# %%
max_words = 10000  # Max number of words in tokenizer
max_len = 62  # Max sequence length
embed_dim = 50
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
X_pad = pad_sequences(X_seq, maxlen=max_len, padding='post')

# %% [markdown]
# ### **Word Embedding Matrix**

# %%
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.ar.300.vec.gz; gunzip cc.ar.300.vec.gz
# Out:
# --2024-05-13 07:54:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.ar.300.vec.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 18.173.166.51, 18.173.166.31, 18.173.166.48, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|18.173.166.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1272365870 (1.2G) [binary/octet-stream]
# Saving to: ‘cc.ar.300.vec.gz’
#
# cc.ar.300.vec.gz    100%[===================>]   1.18G  48.9MB/s    in 24s
#
# 2024-05-13 07:54:33 (51.1 MB/s) - ‘cc.ar.300.vec.gz’ saved [1272365870/1272365870]

# %%
# Step 1: Load FastText Model
import gensim
fasttext_model = gensim.models.KeyedVectors.load_word2vec_format('/content/cc.ar.300.vec', binary=False)

# %%
# Step 2: Create Embedding Matrix from FastText
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, 300))  # FastText vectors are 300-dimensional
for word, i in tokenizer.word_index.items():
    if word in fasttext_model:
        embedding_vector = fasttext_model[word]
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ### **Models**

# %%
# Define a list of deep learning models to experiment with
models = [
    ('CNN', Sequential([
        Embedding(len(tokenizer.word_index) + 1, 300, weights=[embedding_matrix], input_length=max_len, trainable=False),
        Conv1D(128, 5, activation='relu',
               kernel_initializer=RandomNormal(mean=0.0, stddev=0.05),
                bias_initializer=RandomNormal(mean=0.0, stddev=0.05)),
        GlobalMaxPooling1D(),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax')
    ]))

]

# %% [markdown]
# ### **Train 5 cross validation**

# %%
# !export TF_DETERMINISTIC_OPS=1

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# Stratified cross-validation with 10 folds
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits)

# DataFrame to store results
results_df = pd.DataFrame(columns=['Model', 'Fold', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'history'])

output_dir = '/content/drive/MyDrive/seema'
# Training and evaluation loop for each model
for name, model in models:
    print(f'Training and evaluating {name} with {n_splits}-fold stratified cross-validation...')
    fold_results = []

    for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X_pad, y), 1):
        X_train, X_val = X_pad[train_idx], X_pad[val_idx]
        y_train, y_val = y_cat[train_idx], y_cat[val_idx]
        y_val_ =  y[val_idx]
        val_texts = df.iloc[val_idx]['Tweet'].tolist()
        val_subs = df.iloc[val_idx]['Sub'].tolist()
        # Compile the model
        model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])

        # Define callbacks (checkpoint and early stopping)
        checkpoint = ModelCheckpoint(f'{output_dir}/checkpoints/cnn/non_trainable/{name}_fold{fold_idx}.h5', monitor='val_loss', save_best_only=True, verbose=0)
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=0)

        # Train the model with callbacks
        history = model.fit(X_train, y_train, epochs=100, batch_size=128,
                            validation_data=(X_val, y_val),
                            callbacks=[checkpoint, early_stopping],
                            verbose=1)

        # Load the best model for prediction
        best_model = load_model(f'{output_dir}/checkpoints/cnn/non_trainable/{name}_fold{fold_idx}.h5')

        # Evaluate the model on the validation set
        probs = best_model.predict(X_val)
        y_pred = np.argmax(probs, axis=1)
        accuracy = accuracy_score(y_val_, y_pred)
        precision = precision_score(y_val_, y_pred,average='macro')
        recall = recall_score(y_val_, y_pred,average='macro')
        f1 = f1_score(y_val_, y_pred,average='macro')

        # Compute confusion matrix and plot
        cm = confusion_matrix(y_val_, y_pred)
        plot_confusion_matrix(cm, classes=['P-HS', 'R-HS', 'S-HS'], title=f'Confusion Matrix Fold {fold_idx}')
        print(classification_report(y_val_, y_pred, target_names=['P-HS', 'R-HS', 'S-HS']))

        val_df = pd.DataFrame({
            'Tweet': val_texts,
            'True Label': y_val_,
            'Predicted Label':  y_pred,
            'Sub': val_subs
        })
        val_df.to_excel(f'{output_dir}/results/cnn/2nd predictions/cnn_val_set_with_preds_fold_{fold_idx}.xlsx', index=False)


        # Store the results for this fold
        fold_results.append([name, fold_idx, accuracy, precision, recall, f1, history.history])

    # Append fold results to the DataFrame
    results_df = pd.concat([results_df, pd.DataFrame(fold_results, columns=results_df.columns)],
                           ignore_index=True)


    # Calculate average metrics across all folds for this model
    avg_accuracy = np.mean(results_df[results_df['Model'] == name]['Accuracy'])
    avg_precision = np.mean(results_df[results_df['Model'] == name]['Precision'])
    avg_recall = np.mean(results_df[results_df['Model'] == name]['Recall'])
    avg_f1 = np.mean(results_df[results_df['Model'] == name]['F1 Score'])

    print(f'Average metrics for {name}:')
    print(f'Average Accuracy: {avg_accuracy:.4f}')
    print(f'Average Precision: {avg_precision:.4f}')
    print(f'Average Recall: {avg_recall:.4f}')
    print(f'Average F1 Score: {avg_f1:.4f}')
    print('')

# Save results to a CSV file
results_df.to_csv(f'{output_dir}/results/cnn/non_trainable/cnn_model_results.csv', index=False)
# Out:
# Training and evaluating CNN with 5-fold stratified cross-validation...
# Epoch 1/100
# 28/28 [==============================] - 13s 425ms/step - loss: 1.0351 - accuracy: 0.4777 - val_loss: 1.0038 - val_accuracy: 0.5247
# Epoch 2/100
# 28/28 [==============================] - 10s 341ms/step - loss: 0.9801 - accuracy: 0.5574 - val_loss: 0.9739 - val_accuracy: 0.5628
# Epoch 3/100
# 28/28 [==============================] - 9s 308ms/step - loss: 0.9470 - accuracy: 0.5969 - val_loss: 0.9504 - val_accuracy: 0.5930
# Epoch 4/100
# 28/28 [==============================] - 8s 302ms/step - loss: 0.9167 - accuracy: 0.6213 - val_loss: 0.9259 - val_accuracy: 0.6065
# Epoch 5/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.8874 - accuracy: 0.6412 - val_loss: 0.9059 - val_accuracy: 0.6188
# Epoch 6/100
# 28/28 [==============================] - 8s 301ms/step - loss: 0.8586 - accuracy: 0.6539 - val_loss: 0.8860 - val_accuracy: 0.6278
# Epoch 7/100
# 28/28 [==============================] - 8s 272ms/step - loss: 0.8306 - accuracy: 0.6707 - val_loss: 0.8675 - val_accuracy: 0.6368
# Epoch 8/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.8040 - accuracy: 0.6827 - val_loss: 0.8501 - val_accuracy: 0.6401
# Epoch 9/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.7753 - accuracy: 0.6892 - val_loss: 0.8341 - val_accuracy: 0.6502
# Epoch 10/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.7486 - accuracy: 0.7046 - val_loss: 0.8224 - val_accuracy: 0.6513
# Epoch 11/100
# 28/28 [==============================] - 8s 275ms/step - loss: 0.7203 - accuracy: 0.7161 - val_loss: 0.8029 - val_accuracy: 0.6558
# Epoch 12/100
# 28/28 [==============================] - 8s 280ms/step - loss: 0.6956 - accuracy: 0.7279 - val_loss: 0.7884 - val_accuracy: 0.6670
# Epoch 13/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.6682 - accuracy: 0.7414 - val_loss: 0.7746 - val_accuracy: 0.6749
# Epoch 14/100
# 28/28 [==============================] - 4s 156ms/step - loss: 0.6415 - accuracy: 0.7562 - val_loss: 0.7646 - val_accuracy: 0.6726
# Epoch 15/100
# 28/28 [==============================] - 7s 253ms/step - loss: 0.6168 - accuracy: 0.7734 - val_loss: 0.7514 - val_accuracy: 0.6827
# Epoch 16/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.5905 - accuracy: 0.7854 - val_loss: 0.7383 - val_accuracy: 0.6861
# Epoch 17/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.5659 - accuracy: 0.8003 - val_loss: 0.7252 - val_accuracy: 0.6895
# Epoch 18/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.5422 - accuracy: 0.8121 - val_loss: 0.7150 - val_accuracy: 0.6906
# Epoch 19/100
# 28/28 [==============================] - 7s 262ms/step - loss: 0.5175 - accuracy: 0.8283 - val_loss: 0.7067 - val_accuracy: 0.6984
# Epoch 20/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.4949 - accuracy: 0.8348 - val_loss: 0.6967 - val_accuracy: 0.6962
# Epoch 21/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.4730 - accuracy: 0.8488 - val_loss: 0.6905 - val_accuracy: 0.6996
# Epoch 22/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.4529 - accuracy: 0.8555 - val_loss: 0.6825 - val_accuracy: 0.7063
# Epoch 23/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.4307 - accuracy: 0.8684 - val_loss: 0.6753 - val_accuracy: 0.7063
# Epoch 24/100
# 28/28 [==============================] - 13s 472ms/step - loss: 0.4094 - accuracy: 0.8771 - val_loss: 0.6747 - val_accuracy: 0.7085
# Epoch 25/100
# 28/28 [==============================] - 8s 277ms/step - loss: 0.3919 - accuracy: 0.8847 - val_loss: 0.6671 - val_accuracy: 0.7119
# Epoch 26/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3714 - accuracy: 0.8937 - val_loss: 0.6635 - val_accuracy: 0.7141
# Epoch 27/100
# 28/28 [==============================] - 5s 176ms/step - loss: 0.3538 - accuracy: 0.9046 - val_loss: 0.6566 - val_accuracy: 0.7164
# Epoch 28/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.3364 - accuracy: 0.9086 - val_loss: 0.6548 - val_accuracy: 0.7220
# Epoch 29/100
# 28/28 [==============================] - 7s 256ms/step - loss: 0.3193 - accuracy: 0.9212 - val_loss: 0.6514 - val_accuracy: 0.7309
# Epoch 30/100
# 28/28 [==============================] - 8s 274ms/step - loss: 0.3035 - accuracy: 0.9293 - val_loss: 0.6517 - val_accuracy: 0.7231
# Epoch 31/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2870 - accuracy: 0.9383 - val_loss: 0.6453 - val_accuracy: 0.7377
# Epoch 32/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2717 - accuracy: 0.9433 - val_loss: 0.6459 - val_accuracy: 0.7321
# Epoch 33/100
# 28/28 [==============================] - 7s 262ms/step - loss: 0.2574 - accuracy: 0.9518 - val_loss: 0.6544 - val_accuracy: 0.7119
# Epoch 34/100
# 28/28 [==============================] - 4s 148ms/step - loss: 0.2444 - accuracy: 0.9548 - val_loss: 0.6462 - val_accuracy: 0.7276
# Epoch 35/100
# 28/28 [==============================] - 5s 179ms/step - loss: 0.2320 - accuracy: 0.9599 - val_loss: 0.6422 - val_accuracy: 0.7422
# Epoch 36/100
# 28/28 [==============================] - 7s 269ms/step - loss: 0.2185 - accuracy: 0.9655 - val_loss: 0.6397 - val_accuracy: 0.7343
# Epoch 37/100
# 28/28 [==============================] - 8s 277ms/step - loss: 0.2066 - accuracy: 0.9675 - val_loss: 0.6400 - val_accuracy: 0.7410
# Epoch 38/100
# 28/28 [==============================] - 7s 260ms/step - loss: 0.1939 - accuracy: 0.9711 - val_loss: 0.6491 - val_accuracy: 0.7287
# Epoch 39/100
# 28/28 [==============================] - 7s 259ms/step - loss: 0.1822 - accuracy: 0.9748 - val_loss: 0.6445 - val_accuracy: 0.7365
# Epoch 40/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.1712 - accuracy: 0.9770 - val_loss: 0.6425 - val_accuracy: 0.7399
# Epoch 41/100
# 28/28 [==============================] - 5s 159ms/step - loss: 0.1606 - accuracy: 0.9787 - val_loss: 0.6433 - val_accuracy: 0.7410
# Epoch 42/100
# 28/28 [==============================] - 4s 140ms/step - loss: 0.1512 - accuracy: 0.9815 - val_loss: 0.6442 - val_accuracy: 0.7388
# Epoch 43/100
# 28/28 [==============================] - 5s 179ms/step - loss: 0.1422 - accuracy: 0.9829 - val_loss: 0.6454 - val_accuracy: 0.7388
# Epoch 44/100
# 28/28 [==============================] - 8s 279ms/step - loss: 0.1333 - accuracy: 0.9863 - val_loss: 0.6460 - val_accuracy: 0.7343
# Epoch 45/100
# 28/28 [==============================] - 7s 267ms/step - loss: 0.1254 - accuracy: 0.9882 - val_loss: 0.6501 - val_accuracy: 0.7365
# Epoch 46/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.1176 - accuracy: 0.9907 - val_loss: 0.6500 - val_accuracy: 0.7365
# 28/28 [==============================] - 1s 37ms/step
#               precision    recall  f1-score   support
#
#         P-HS       0.75      0.76      0.76       370
#         R-HS       0.68      0.51      0.58       136
#         S-HS       0.73      0.79      0.76       386
#
#     accuracy                           0.73       892
#    macro avg       0.72      0.69      0.70       892
# weighted avg       0.73      0.73      0.73       892
#
# Epoch 1/100
# 28/28 [==============================] - 12s 393ms/step - loss: 0.3176 - accuracy: 0.9094 - val_loss: 0.2101 - val_accuracy: 0.9720
# Epoch 2/100
# 28/28 [==============================] - 8s 290ms/step - loss: 0.2945 - accuracy: 0.9206 - val_loss: 0.2108 - val_accuracy: 0.9709
# Epoch 3/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2783 - accuracy: 0.9268 - val_loss: 0.2094 - val_accuracy: 0.9675
# Epoch 4/100
# 28/28 [==============================] - 6s 199ms/step - loss: 0.2626 - accuracy: 0.9338 - val_loss: 0.2086 - val_accuracy: 0.9664
# Epoch 5/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.2496 - accuracy: 0.9372 - val_loss: 0.2067 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 6s 210ms/step - loss: 0.2344 - accuracy: 0.9445 - val_loss: 0.2053 - val_accuracy: 0.9641
# Epoch 7/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2216 - accuracy: 0.9481 - val_loss: 0.2048 - val_accuracy: 0.9619
# Epoch 8/100
# 28/28 [==============================] - 8s 305ms/step - loss: 0.2095 - accuracy: 0.9543 - val_loss: 0.2032 - val_accuracy: 0.9619
# Epoch 9/100
# 28/28 [==============================] - 8s 270ms/step - loss: 0.1972 - accuracy: 0.9602 - val_loss: 0.2009 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.1862 - accuracy: 0.9627 - val_loss: 0.1996 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 5s 174ms/step - loss: 0.1752 - accuracy: 0.9691 - val_loss: 0.1978 - val_accuracy: 0.9619
# Epoch 12/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.1652 - accuracy: 0.9731 - val_loss: 0.1959 - val_accuracy: 0.9585
# Epoch 13/100
# 28/28 [==============================] - 5s 194ms/step - loss: 0.1553 - accuracy: 0.9756 - val_loss: 0.1945 - val_accuracy: 0.9574
# Epoch 14/100
# 28/28 [==============================] - 8s 305ms/step - loss: 0.1464 - accuracy: 0.9790 - val_loss: 0.1933 - val_accuracy: 0.9596
# Epoch 15/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.1375 - accuracy: 0.9818 - val_loss: 0.1925 - val_accuracy: 0.9552
# Epoch 16/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.1292 - accuracy: 0.9832 - val_loss: 0.1903 - val_accuracy: 0.9540
# Epoch 17/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.1217 - accuracy: 0.9871 - val_loss: 0.1892 - val_accuracy: 0.9540
# Epoch 18/100
# 28/28 [==============================] - 5s 184ms/step - loss: 0.1146 - accuracy: 0.9879 - val_loss: 0.1882 - val_accuracy: 0.9552
# Epoch 19/100
# 28/28 [==============================] - 4s 145ms/step - loss: 0.1072 - accuracy: 0.9899 - val_loss: 0.1859 - val_accuracy: 0.9540
# Epoch 20/100
# 28/28 [==============================] - 5s 194ms/step - loss: 0.1009 - accuracy: 0.9907 - val_loss: 0.1860 - val_accuracy: 0.9507
# Epoch 21/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0949 - accuracy: 0.9930 - val_loss: 0.1845 - val_accuracy: 0.9518
# Epoch 22/100
# 28/28 [==============================] - 7s 261ms/step - loss: 0.0893 - accuracy: 0.9933 - val_loss: 0.1845 - val_accuracy: 0.9462
# Epoch 23/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.0842 - accuracy: 0.9944 - val_loss: 0.1833 - val_accuracy: 0.9462
# Epoch 24/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0790 - accuracy: 0.9952 - val_loss: 0.1824 - val_accuracy: 0.9484
# Epoch 25/100
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0740 - accuracy: 0.9964 - val_loss: 0.1815 - val_accuracy: 0.9428
# Epoch 26/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.0699 - accuracy: 0.9964 - val_loss: 0.1805 - val_accuracy: 0.9473
# Epoch 27/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0656 - accuracy: 0.9972 - val_loss: 0.1799 - val_accuracy: 0.9439
# Epoch 28/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.0619 - accuracy: 0.9966 - val_loss: 0.1799 - val_accuracy: 0.9417
# Epoch 29/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.0581 - accuracy: 0.9969 - val_loss: 0.1787 - val_accuracy: 0.9428
# Epoch 30/100
# 28/28 [==============================] - 7s 258ms/step - loss: 0.0547 - accuracy: 0.9969 - val_loss: 0.1787 - val_accuracy: 0.9428
# Epoch 31/100
# 28/28 [==============================] - 9s 313ms/step - loss: 0.0515 - accuracy: 0.9972 - val_loss: 0.1786 - val_accuracy: 0.9406
# Epoch 32/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.0485 - accuracy: 0.9969 - val_loss: 0.1780 - val_accuracy: 0.9406
# Epoch 33/100
# 28/28 [==============================] - 4s 140ms/step - loss: 0.0457 - accuracy: 0.9978 - val_loss: 0.1786 - val_accuracy: 0.9383
# Epoch 34/100
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0433 - accuracy: 0.9975 - val_loss: 0.1776 - val_accuracy: 0.9372
# Epoch 35/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.0412 - accuracy: 0.9980 - val_loss: 0.1773 - val_accuracy: 0.9383
# Epoch 36/100
# 28/28 [==============================] - 7s 263ms/step - loss: 0.0388 - accuracy: 0.9980 - val_loss: 0.1769 - val_accuracy: 0.9327
# Epoch 37/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0368 - accuracy: 0.9983 - val_loss: 0.1772 - val_accuracy: 0.9339
# Epoch 38/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0350 - accuracy: 0.9980 - val_loss: 0.1776 - val_accuracy: 0.9372
# Epoch 39/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.0331 - accuracy: 0.9983 - val_loss: 0.1777 - val_accuracy: 0.9372
# Epoch 40/100
# 28/28 [==============================] - 5s 195ms/step - loss: 0.0316 - accuracy: 0.9989 - val_loss: 0.1776 - val_accuracy: 0.9339
# Epoch 41/100
# 28/28 [==============================] - 7s 255ms/step - loss: 0.0300 - accuracy: 0.9986 - val_loss: 0.1775 - val_accuracy: 0.9350
# Epoch 42/100
# 28/28 [==============================] - 7s 268ms/step - loss: 0.0285 - accuracy: 0.9989 - val_loss: 0.1774 - val_accuracy: 0.9350
# Epoch 43/100
# 28/28 [==============================] - 8s 273ms/step - loss: 0.0271 - accuracy: 0.9992 - val_loss: 0.1781 - val_accuracy: 0.9316
# Epoch 44/100
# 28/28 [==============================] - 7s 267ms/step - loss: 0.0260 - accuracy: 0.9989 - val_loss: 0.1781 - val_accuracy: 0.9339
# Epoch 45/100
# 28/28 [==============================] - 7s 267ms/step - loss: 0.0247 - accuracy: 0.9989 - val_loss: 0.1788 - val_accuracy: 0.9339
# Epoch 46/100
# 28/28 [==============================] - 8s 275ms/step - loss: 0.0237 - accuracy: 0.9992 - val_loss: 0.1781 - val_accuracy: 0.9305
# 28/28 [==============================] - 1s 34ms/step
#               precision    recall  f1-score   support
#
#         P-HS       0.95      0.94      0.94       370
#         R-HS       0.85      0.86      0.86       136
#         S-HS       0.95      0.95      0.95       386
#
#     accuracy                           0.93       892
#    macro avg       0.92      0.92      0.92       892
# weighted avg       0.93      0.93      0.93       892
#
# Epoch 1/100
# 28/28 [==============================] - 12s 369ms/step - loss: 0.0728 - accuracy: 0.9851 - val_loss: 0.0384 - val_accuracy: 0.9966
# Epoch 2/100
# 28/28 [==============================] - 7s 247ms/step - loss: 0.0598 - accuracy: 0.9913 - val_loss: 0.0391 - val_accuracy: 0.9955
# Epoch 3/100
# 28/28 [==============================] - 4s 152ms/step - loss: 0.0520 - accuracy: 0.9947 - val_loss: 0.0398 - val_accuracy: 0.9955
# Epoch 4/100
# 28/28 [==============================] - 4s 139ms/step - loss: 0.0466 - accuracy: 0.9972 - val_loss: 0.0398 - val_accuracy: 0.9955
# Epoch 5/100
# 28/28 [==============================] - 7s 238ms/step - loss: 0.0424 - accuracy: 0.9980 - val_loss: 0.0398 - val_accuracy: 0.9933
# Epoch 6/100
# 28/28 [==============================] - 8s 276ms/step - loss: 0.0382 - accuracy: 0.9992 - val_loss: 0.0399 - val_accuracy: 0.9933
# Epoch 7/100
# 28/28 [==============================] - 8s 279ms/step - loss: 0.0346 - accuracy: 0.9994 - val_loss: 0.0400 - val_accuracy: 0.9933
# Epoch 8/100
# 28/28 [==============================] - 7s 260ms/step - loss: 0.0317 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9933
# Epoch 9/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0292 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9933
# Epoch 10/100
# 28/28 [==============================] - 4s 154ms/step - loss: 0.0272 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9933
# Epoch 11/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0251 - accuracy: 0.9997 - val_loss: 0.0402 - val_accuracy: 0.9933
# 28/28 [==============================] - 1s 29ms/step
#               precision    recall  f1-score   support
#
#         P-HS       1.00      1.00      1.00       370
#         R-HS       1.00      0.99      0.99       136
#         S-HS       0.99      1.00      1.00       385
#
#     accuracy                           1.00       891
#    macro avg       1.00      0.99      1.00       891
# weighted avg       1.00      1.00      1.00       891
#
# Epoch 1/100
# 28/28 [==============================] - 11s 360ms/step - loss: 0.0649 - accuracy: 0.9896 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 2/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0544 - accuracy: 0.9944 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 5s 186ms/step - loss: 0.0479 - accuracy: 0.9964 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 4s 139ms/step - loss: 0.0430 - accuracy: 0.9978 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 6s 210ms/step - loss: 0.0393 - accuracy: 0.9983 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.0355 - accuracy: 0.9989 - val_loss: 0.0283 - val_accuracy: 0.9989
# Epoch 7/100
# 28/28 [==============================] - 6s 195ms/step - loss: 0.0323 - accuracy: 0.9992 - val_loss: 0.0279 - val_accuracy: 0.9989
# Epoch 8/100
# 28/28 [==============================] - 7s 258ms/step - loss: 0.0298 - accuracy: 0.9992 - val_loss: 0.0273 - val_accuracy: 0.9989
# Epoch 9/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.0275 - accuracy: 0.9992 - val_loss: 0.0272 - val_accuracy: 0.9989
# Epoch 10/100
# 28/28 [==============================] - 7s 267ms/step - loss: 0.0257 - accuracy: 0.9989 - val_loss: 0.0272 - val_accuracy: 0.9989
# Epoch 11/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0240 - accuracy: 0.9992 - val_loss: 0.0263 - val_accuracy: 0.9989
# Epoch 12/100
# 28/28 [==============================] - 4s 157ms/step - loss: 0.0219 - accuracy: 0.9992 - val_loss: 0.0262 - val_accuracy: 0.9989
# Epoch 13/100
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0206 - accuracy: 0.9992 - val_loss: 0.0258 - val_accuracy: 0.9989
# Epoch 14/100
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0194 - accuracy: 0.9989 - val_loss: 0.0257 - val_accuracy: 0.9989
# Epoch 15/100
# 28/28 [==============================] - 9s 315ms/step - loss: 0.0179 - accuracy: 0.9994 - val_loss: 0.0251 - val_accuracy: 0.9989
# Epoch 16/100
# 28/28 [==============================] - 7s 254ms/step - loss: 0.0168 - accuracy: 0.9992 - val_loss: 0.0252 - val_accuracy: 0.9989
# Epoch 17/100
# 28/28 [==============================] - 8s 301ms/step - loss: 0.0159 - accuracy: 0.9992 - val_loss: 0.0247 - val_accuracy: 0.9989
# Epoch 18/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0148 - accuracy: 0.9994 - val_loss: 0.0246 - val_accuracy: 0.9989
# Epoch 19/100
# 28/28 [==============================] - 5s 193ms/step - loss: 0.0140 - accuracy: 0.9994 - val_loss: 0.0243 - val_accuracy: 0.9989
# Epoch 20/100
# 28/28 [==============================] - 4s 156ms/step - loss: 0.0136 - accuracy: 0.9992 - val_loss: 0.0242 - val_accuracy: 0.9989
# Epoch 21/100
# 28/28 [==============================] - 5s 173ms/step - loss: 0.0126 - accuracy: 0.9992 - val_loss: 0.0244 - val_accuracy: 0.9989
# Epoch 22/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.0124 - accuracy: 0.9992 - val_loss: 0.0237 - val_accuracy: 0.9978
# Epoch 23/100
# 28/28 [==============================] - 8s 280ms/step - loss: 0.0112 - accuracy: 0.9992 - val_loss: 0.0240 - val_accuracy: 0.9978
# Epoch 24/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.0107 - accuracy: 0.9989 - val_loss: 0.0234 - val_accuracy: 0.9978
# Epoch 25/100
# 28/28 [==============================] - 8s 278ms/step - loss: 0.0106 - accuracy: 0.9992 - val_loss: 0.0233 - val_accuracy: 0.9978
# Epoch 26/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0098 - accuracy: 0.9992 - val_loss: 0.0235 - val_accuracy: 0.9978
# Epoch 27/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.0233 - val_accuracy: 0.9978
# Epoch 28/100
# 28/28 [==============================] - 7s 259ms/step - loss: 0.0098 - accuracy: 0.9994 - val_loss: 0.0237 - val_accuracy: 0.9978
# Epoch 29/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.0089 - accuracy: 0.9994 - val_loss: 0.0229 - val_accuracy: 0.9978
# Epoch 30/100
# 28/28 [==============================] - 7s 267ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.0233 - val_accuracy: 0.9978
# Epoch 31/100
# 28/28 [==============================] - 8s 275ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0239 - val_accuracy: 0.9978
# Epoch 32/100
# 28/28 [==============================] - 9s 314ms/step - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.0229 - val_accuracy: 0.9978
# Epoch 33/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.0236 - val_accuracy: 0.9966
# Epoch 34/100
# 28/28 [==============================] - 7s 259ms/step - loss: 0.0070 - accuracy: 0.9994 - val_loss: 0.0230 - val_accuracy: 0.9978
# Epoch 35/100
# 28/28 [==============================] - 6s 224ms/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.0228 - val_accuracy: 0.9978
# Epoch 36/100
# 28/28 [==============================] - 4s 151ms/step - loss: 0.0063 - accuracy: 0.9997 - val_loss: 0.0233 - val_accuracy: 0.9966
# Epoch 37/100
# 28/28 [==============================] - 5s 174ms/step - loss: 0.0064 - accuracy: 0.9997 - val_loss: 0.0230 - val_accuracy: 0.9978
# Epoch 38/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.0060 - accuracy: 0.9994 - val_loss: 0.0228 - val_accuracy: 0.9978
# Epoch 39/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.0226 - val_accuracy: 0.9978
# Epoch 40/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0233 - val_accuracy: 0.9966
# Epoch 41/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0227 - val_accuracy: 0.9978
# Epoch 42/100
# 28/28 [==============================] - 5s 191ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9966
# Epoch 43/100
# 28/28 [==============================] - 4s 140ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0228 - val_accuracy: 0.9966
# Epoch 44/100
# 28/28 [==============================] - 4s 150ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9966
# Epoch 45/100
# 28/28 [==============================] - 7s 245ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9966
# Epoch 46/100
# 28/28 [==============================] - 7s 250ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0236 - val_accuracy: 0.9966
# Epoch 47/100
# 28/28 [==============================] - 8s 277ms/step - loss: 0.0046 - accuracy: 0.9997 - val_loss: 0.0233 - val_accuracy: 0.9966
# Epoch 48/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0225 - val_accuracy: 0.9978
# Epoch 49/100
# 28/28 [==============================] - 8s 275ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0249 - val_accuracy: 0.9966
# Epoch 50/100
# 28/28 [==============================] - 4s 155ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0228 - val_accuracy: 0.9966
# Epoch 51/100
# 28/28 [==============================] - 4s 140ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.0229 - val_accuracy: 0.9966
# Epoch 52/100
# 28/28 [==============================] - 5s 190ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.0234 - val_accuracy: 0.9966
# Epoch 53/100
# 28/28 [==============================] - 8s 272ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.0230 - val_accuracy: 0.9966
# Epoch 54/100
# 28/28 [==============================] - 8s 275ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.0241 - val_accuracy: 0.9966
# Epoch 55/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0259 - val_accuracy: 0.9966
# Epoch 56/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.0231 - val_accuracy: 0.9966
# Epoch 57/100
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0248 - val_accuracy: 0.9966
# Epoch 58/100
# 28/28 [==============================] - 4s 151ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0230 - val_accuracy: 0.9955
# 28/28 [==============================] - 1s 30ms/step
#               precision    recall  f1-score   support
#
#         P-HS       1.00      1.00      1.00       369
#         R-HS       0.99      1.00      1.00       136
#         S-HS       1.00      1.00      1.00       386
#
#     accuracy                           1.00       891
#    macro avg       1.00      1.00      1.00       891
# weighted avg       1.00      1.00      1.00       891
#
# Epoch 1/100
# 28/28 [==============================] - 10s 331ms/step - loss: 0.0094 - accuracy: 0.9992 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 2/100
# 28/28 [==============================] - 7s 262ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 8s 274ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 8s 290ms/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 5/100
# 28/28 [==============================] - 8s 280ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 0.0032 - val_accuracy: 0.9989
# Epoch 6/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 0.0040 - val_accuracy: 0.9989
# Epoch 7/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 8/100
# 28/28 [==============================] - 8s 272ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.0037 - val_accuracy: 0.9989
# Epoch 9/100
# 28/28 [==============================] - 8s 269ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 10/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 11/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0037 - val_accuracy: 0.9989
# 28/28 [==============================] - 1s 17ms/step
#               precision    recall  f1-score   support
#
#         P-HS       1.00      1.00      1.00       369
#         R-HS       1.00      1.00      1.00       136
#         S-HS       1.00      1.00      1.00       386
#
#     accuracy                           1.00       891
#    macro avg       1.00      1.00      1.00       891
# weighted avg       1.00      1.00      1.00       891
#
# Average metrics for CNN:
# Average Accuracy: 0.9323
# Average Precision: 0.9264
# Average Recall: 0.9191
# Average F1 Score: 0.9218

# %%
import pandas as pd
results_df = pd.read_csv(f'{output_dir}/results/cnn/non_trainable/cnn_model_results.csv')

# %%
results_df

# %%
import ast

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the number of models and folds
num_models = len(results_df['Model'].unique())
num_folds = len(results_df['Fold'].unique())

# Create subplots based on the number of models and folds
fig, axes = plt.subplots(num_models, num_folds, figsize=(20, 4*1))
fig.suptitle('Training & Validation Loss of Each Model for Each Fold', fontsize=16)

# Loop through each model and fold to plot the training history
for i, model in enumerate(results_df['Model'].unique()):
    for j, fold in enumerate(results_df['Fold'].unique()):
        # Filter the dataframe for the specific model and fold
        data = results_df[(results_df['Model'] == model) & (results_df['Fold'] == fold)]

        # Extract the history dictionary from the first row
        history = ast.literal_eval(data['history'].values[0])

        # Plot the training loss
        axes[j].plot(history['loss'], label='Training Loss')
        axes[j].plot(history['val_loss'], label='Validation Loss')
        axes[j].set_title(f'{model} - Fold {fold}')
        axes[j].set_xlabel('Epoch')
        axes[j].set_ylabel('Loss')
        axes[j].legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# Create subplots based on the number of models and folds
fig, axes = plt.subplots(num_models, num_folds, figsize=(20, 4*num_models))
fig.suptitle('Training & Validation Accuracy of Each Model for Each Fold', fontsize=16)

# Loop through each model and fold to plot the training history
for i, model in enumerate(results_df['Model'].unique()):
    for j, fold in enumerate(results_df['Fold'].unique()):
        # Filter the dataframe for the specific model and fold
        data = results_df[(results_df['Model'] == model) & (results_df['Fold'] == fold)]

        # Extract the history dictionary from the first row
        history = ast.literal_eval(data['history'].values[0])

        # Plot the training loss
        axes[j].plot(history['accuracy'], label='Training Acc')
        axes[j].plot(history['val_accuracy'], label='Validation Acc')
        axes[j].set_title(f'{model} - Fold {fold}')
        axes[j].set_xlabel('Epoch')
        axes[j].set_ylabel('Accuracy')
        axes[j].legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
